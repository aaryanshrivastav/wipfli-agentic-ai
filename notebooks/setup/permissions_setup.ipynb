# %%
# %sql
GRANT USE CATALOG
ON CATALOG agentdb
TO `account users`;

# %%
# %sql
GRANT USE SCHEMA
ON SCHEMA agentdb.bronze
TO `account users`;

# %%
# %sql
GRANT USE SCHEMA
ON SCHEMA agentdb.silver
TO `account users`;

# %%
# %sql
GRANT USE SCHEMA
ON SCHEMA agentdb.gold
TO `account users`;

# %%
# %sql
SHOW GRANTS ON CATALOG agentdb;
