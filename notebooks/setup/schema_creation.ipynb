# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agentdb.bronze;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agentdb.silver;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agentdb.gold;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agentdb.ml;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agentdb.monitoring;

# %%
# %sql
SHOW SCHEMAS IN agentdb;
